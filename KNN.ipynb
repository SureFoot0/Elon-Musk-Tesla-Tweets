# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report,confusion_matrix

# %%
df = pd.read_csv("Final Data.csv")
df = df.drop(columns=["Unnamed: 0", "Date", "Tweet", "text", "Tweet URL", "Open", "High", "Low", "Close", "Adj Close", "Volume", "Price Change"])
df.head()
# Out:
#    Percent Change  Positive  Neutral  Negative  Compound  TESLA
# 0             1.0     0.250    0.750       0.0    0.8997      1
# 1             0.0     0.000    1.000       0.0    0.0000      0
# 2             6.0     0.133    0.867       0.0    0.3818      0
# 3             1.0     0.000    1.000       0.0    0.0000      1
# 4            -1.0     0.233    0.767       0.0    0.8705      0

# %%
scaler = StandardScaler()

# %%
scaler.fit(df.drop('Percent Change',axis=1))
# Out:
# StandardScaler()

# %%
scaled_features = scaler.transform(df.drop('Percent Change',axis=1))

# %%
scaled_features
# Out:
# array([[ 1.01224315, -0.72627006, -0.43002613,  1.88200505,  1.89386765],
#        [-0.80800302,  0.95932027, -0.43002613, -0.53500873, -0.52802   ],
#        [ 0.16036794,  0.06258621, -0.43002613,  0.49068412, -0.52802   ],
#        ...,
#        [ 0.00746726,  0.2041758 , -0.43002613,  0.59733684,  1.89386765],
#        [ 0.08027711, -0.34869783,  0.55933661, -0.05708636, -0.52802   ],
#        [-0.80800302,  0.95932027, -0.43002613, -0.53500873, -0.52802   ]])

# %%
df_feat = pd.DataFrame(scaled_features,columns = df.columns[:-1])

# %%
df_feat.head()
# Out:
#    Percent Change  Positive   Neutral  Negative  Compound
# 0        1.012243 -0.726270 -0.430026  1.882005  1.893868
# 1       -0.808003  0.959320 -0.430026 -0.535009 -0.528020
# 2        0.160368  0.062586 -0.430026  0.490684 -0.528020
# 3       -0.808003  0.959320 -0.430026 -0.535009  1.893868
# 4        0.888466 -0.611650 -0.430026  1.803560 -0.528020

# %%
X = df_feat
y=df['Percent Change']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
for numofneighbors in range(1, 100, 10):
    print(numofneighbors)
    knn = KNeighborsClassifier(n_neighbors=numofneighbors)
    knn.fit(X_train,y_train)
    pred = knn.predict(X_test)
    print(classification_report(y_test,pred))
# Out:
# 1
#               precision    recall  f1-score   support
#
#        -19.0       0.00      0.00      0.00         0
#        -13.0       0.00      0.00      0.00         1
#        -12.0       0.00      0.00      0.00         0
#        -10.0       0.00      0.00      0.00         1
#         -9.0       0.00      0.00      0.00         0
#         -8.0       0.00      0.00      0.00         2
#         -7.0       0.00      0.00      0.00         1
#         -6.0       0.00      0.00      0.00         4
#         -5.0       0.00      0.00      0.00        10
#         -4.0       0.00      0.00      0.00        10
#         -3.0       0.00      0.00      0.00         9
#         -2.0       0.09      0.30      0.14        30
#         -1.0       0.09      0.05      0.06        41
#          0.0       0.13      0.16      0.15        43
#          1.0       0.06      0.03      0.04        39
#          2.0       0.06      0.03      0.04        35
# ...

# %%
print(classification_report(y_test,pred))
#print(confusion_matrix(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#        -13.0       0.00      0.00      0.00         1
#        -12.0       0.00      0.00      0.00         0
#        -10.0       0.00      0.00      0.00         1
#         -8.0       0.50      0.50      0.50         2
#         -7.0       0.00      0.00      0.00         1
#         -6.0       0.00      0.00      0.00         4
#         -5.0       0.50      0.20      0.29        10
#         -4.0       0.27      0.30      0.29        10
#         -3.0       0.10      0.11      0.11         9
#         -2.0       0.30      0.33      0.32        30
#         -1.0       0.31      0.32      0.31        41
#          0.0       0.31      0.35      0.33        43
#          1.0       0.27      0.28      0.28        39
#          2.0       0.27      0.20      0.23        35
#          3.0       0.35      0.38      0.36        16
#          4.0       0.11      0.12      0.12         8
# ...
